# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivesh-1999/Customer-segmentation-RFM-model/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (25.0)

# %%
import pandas as pd
from datetime import datetime as dt, timedelta
import plotly.express as px
import plotly.graph_objects as go
import plotly.colors

# %%
data = pd.read_csv('/content/online_retail.csv')

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID Country
# 541904  2011-12-09 12:50:00       0.85     12680.0  France
# 541905  2011-12-09 12:50:00       2.10     12680.0  France
# 541906  2011-12-09 12:50:00       4.15     12680.0  France
# 541907  2011-12-09 12:50:00       4.15     12680.0  France
# 541908  2011-12-09 12:50:00       4.95     12680.0  France

# %%
data.dropna(subset=['CustomerID'], inplace=True)

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data['TotalAmount'] = data['Quantity'] * data['UnitPrice']

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34

# %%
reference_date = pd.Timestamp(dt.now().date())

# %%
reference_date = data['InvoiceDate'].max() + timedelta(days=1)

# %%
rfm = data.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (reference_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalAmount': 'sum'
})

# %%
rfm.rename(columns={
    'InvoiceDate': 'Recency',
    'InvoiceNo': 'Frequency',
    'TotalAmount': 'Value'
}, inplace=True)

# %%
rfm.head()
# Out:
#             Recency  Frequency    Value
# CustomerID
# 12346.0         326          2     0.00
# 12347.0           2        182  4310.00
# 12348.0          75         31  1797.24
# 12349.0          19         73  1757.55
# 12350.0         310         17   334.40

# %%
# Define quantiles
quantiles = rfm.quantile(q=[0.25, 0.5, 0.75])

#Assign RFM SCORES
def RScore(x, p, d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1

def FScore(x, p, d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4

def MScore(x, p, d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4

rfm['R'] = rfm['Recency'].apply(RScore, args=('Recency', quantiles))
rfm['F'] = rfm['Frequency'].apply(FScore, args=('Frequency', quantiles))
rfm['M'] = rfm['Value'].apply(MScore, args=('Value', quantiles))

# %%
rfm.head()
# Out:
#             Recency  Frequency    Value  R  F  M
# CustomerID
# 12346.0         326          2     0.00  1  1  1
# 12347.0           2        182  4310.00  4  4  4
# 12348.0          75         31  1797.24  2  2  4
# 12349.0          19         73  1757.55  3  3  4
# 12350.0         310         17   334.40  1  1  2

# %%
rfm['RFM_Score'] = rfm['R'].astype(str) + rfm['F'].astype(str) + rfm['M'].astype(str)

# %%
rfm.head()
# Out:
#             Recency  Frequency    Value  R  F  M RFM_Score
# CustomerID
# 12346.0         326          2     0.00  1  1  1       111
# 12347.0           2        182  4310.00  4  4  4       444
# 12348.0          75         31  1797.24  2  2  4       224
# 12349.0          19         73  1757.55  3  3  4       334
# 12350.0         310         17   334.40  1  1  2       112

# %%
segment_labels =['Low-Value', 'Mid-Value', 'High-Value']

def assign_segment(score):
  if score < 5:
    return 'Low-Value'
  elif score < 9:
    return 'Mid-Value'
  else:
    return 'High-Value'

# Calculate numerical RFM score by summing R, F, and M
rfm['RFM_Score_Numeric'] = rfm['R'] + rfm['F'] + rfm['M']

# Apply the assign_segment function to the numerical score
rfm['RFM_Segment_Label'] = rfm['RFM_Score_Numeric'].apply(assign_segment)

rfm.head()
# Out:
#             Recency  Frequency    Value  R  F  M RFM_Score  RFM_Score_Numeric  \
# CustomerID
# 12346.0         326          2     0.00  1  1  1       111                  3
# 12347.0           2        182  4310.00  4  4  4       444                 12
# 12348.0          75         31  1797.24  2  2  4       224                  8
# 12349.0          19         73  1757.55  3  3  4       334                 10
# 12350.0         310         17   334.40  1  1  2       112                  4
#
#            RFM_Segment_Label
# CustomerID
# 12346.0            Low-Value
# 12347.0           High-Value
# 12348.0            Mid-Value
# 12349.0           High-Value
# 12350.0            Low-Value

# %%
segment_counts = rfm['RFM_Segment_Label'].value_counts().reset_index()
segment_counts.columns = ['RFM_Segment_Label', 'Count']
segment_counts = segment_counts.sort_values(by='RFM_Segment_Label')

# %%
# Create the bar chart using Plotly

fig = px.bar(segment_counts, x='RFM_Segment_Label', y='Count',
             labels={'RFM_Segment_Label': 'RFM Segment', 'Count': 'Count'},
             title='Distribution of RFM Segments',
             color='RFM_Segment_Label',
             color_discrete_sequence=px.colors.qualitative.Pastel)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="92af708f-e66a-4587-928f-b2d696d8234f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92af708f-e66a-4587-928f-b2d696d8234f")) {                    Plotly.newPlot(                        "92af708f-e66a-4587-928f-b2d696d8234f",                        [{"alignmentgroup":"True","hovertemplate":"RFM Segment=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High-Value","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"High-Value","offsetgroup":"High-Value","orientation":"v","showlegend":true,"textposition":"auto","x":["High-Value"],"xaxis":"x","y":[1690],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RFM Segment=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low-Value","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Low-Value","offsetgroup":"Low-Value","orientation":"v","showlegend":true,"textposition":"auto","x":["Low-Value"],"xaxis":"x","y":[783],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"RFM Segment=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mid-Value","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Mid-Value","offsetgroup":"Mid-Value","orientation":"v","showlegend":true,"textposition":"auto","x":["Mid-Value"],"xaxis":"x","y":[1899],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...

# %%
rfm['RFM_Customer_Segments']='Vip/Loyal'

rfm.loc[rfm['RFM_Score_Numeric']>=9,'RFM_Customer_Segments']='Potential Loyal'
rfm.loc[(rfm['RFM_Score_Numeric']>=6) & (rfm['RFM_Score_Numeric']<9),'RFM_Customer_Segments']='AT Risk Customers'
rfm.loc[(rfm['RFM_Score_Numeric']>=5) & (rfm['RFM_Score_Numeric']<5),'RFM_Customer_Segments']="Can't Lose"
rfm.loc[rfm['RFM_Score_Numeric']==4,'RFM_Customer_Segments']="Lost"
segment_counts = rfm.groupby('RFM_Customer_Segments').size().reset_index(name='Count')
segment_product_counts = segment_counts.sort_values('Count',ascending=False)

# %%
# Create the treemap
fig = px.treemap(segment_product_counts, path=['RFM_Customer_Segments'], values='Count',
                  title='RFM Customer Segments',
                  color='RFM_Customer_Segments',
                 color_discrete_sequence=px.colors.qualitative.Pastel)
#Display the treemap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61ae4e11-f33b-47f0-926e-d3ce0a52b1ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61ae4e11-f33b-47f0-926e-d3ce0a52b1ba")) {                    Plotly.newPlot(                        "61ae4e11-f33b-47f0-926e-d3ce0a52b1ba",                        [{"branchvalues":"total","customdata":[["Lost"],["Vip\u002fLoyal"],["AT Risk Customers"],["Potential Loyal"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eCount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eRFM_Customer_Segments=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Lost","Vip\u002fLoyal","AT Risk Customers","Potential Loyal"],"labels":["Lost","Vip\u002fLoyal","AT Risk Customers","Potential Loyal"],"marker":{"colors":["rgb(102, 197, 204)","rgb(246, 207, 113)","rgb(248, 156, 116)","rgb(220, 176, 242)"]},"name":"","parents":["","","",""],"values":[391,909,1382,1690],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorb ...

# %%
vip_segment = rfm[rfm['RFM_Customer_Segments'] == 'Vip/Loyal']

# %%
fig = go.Figure()
fig.add_trace(go.Box(
    y=vip_segment['Recency'],
    name='Recency',
    marker_color='blue'))
fig.add_trace(go.Box(
    y=vip_segment['Frequency'],
    name='Frequency',
    marker_color='green'))
fig.add_trace(go.Box(
    y=vip_segment['Value'],
    name='Value',
    marker_color='red'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4a5543ee-007c-4afa-ba80-e0eb9c1521ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a5543ee-007c-4afa-ba80-e0eb9c1521ba")) {                    Plotly.newPlot(                        "4a5543ee-007c-4afa-ba80-e0eb9c1521ba",                        [{"marker":{"color":"blue"},"name":"Recency","y":[326,204,287,291,303,323,217,195,43,100,367,22,243,156,53,63,166,338,18,301,284,66,39,198,166,358,311,303,261,282,316,247,40,239,39,317,190,365,278,22,232,276,239,155,335,30,325,359,330,372,20,64,292,71,371,180,234,353,333,372,211,192,374,257,335,360,184,168,261,45,281,178,214,322,262,145,283,173,267,290,373,52,283,366,84,143,88,205,265,149,128,161,64,26,301,288,198,156,240,19,196,318,174,323,372,357,291,212,25,250,373,192,267,179,234,40,239,269,262,274,333,26,144,22,313,282,45,268,61,200,273,202,81,226,212,262,93,51,61,269,263,31,323,156,360,268,165,155,351,72,316,154,173,277,70,66,269,67,50,257,281,330,75,204,185,192,18,107,74,255,92,29,183,236,198,232,233,105,312,283,312,244,261,50,30,79,205,183,319,216,173,309,36,313,174,117,257,35,179,301,151,152,187,183,325,39,318,303,32,219,247,217,219,200,18,241,374,152,204,251,367,310,255,367,305,158,22,359,18,159,253,65,245,358,189,204,93,326,352,23,169,58,171,169,35,79,361,154,372,21,22,146,287,30,155,225,122,63,285,33,284,267,267,21,125,33,325,138,23,144,354,84,373,234,266,297,331,202,107,218,239,372,43,247,81,373,326,184,235,155,332,226,197,40,19,108,207,235,158,219,39,260,165,215,366,320,295,358,185,297,218,311,218,299,306,181,311,110,98,254,165,150,207,26,312,301,88,58,186,151,311,18,152,64,372,41,372,306,275,72,239,204,185,312,263,266,51,22,157,77,169,87,27,24,372,71,188,107,209,265,214,199,24,274,248,294,264,44,281,320,26,29,166,197,367,53,268,29,210,20,253,207,336,254,148,154,32,253,147,271,247,128,246,212,159,267,72,90,170,199,270,274,373,257,308,215,43,182,241,246,23,66,170,233,240,226,219,357,373,26,325,323,72,260,367,154,225,239,319,366,226,234,311,239,277,238,122,149,281,169,135,324,338,47,172,50,290,271,199,327,284,334,208,54,333,366,373,29,144,186,270,326,290,149,171,25,323,38,23,262,131,264,331,313,262,25,354,29,161,363,331,156,45,84,33,114,217,278,352,50,19,162,177,253,289,35,337,36,301,179,158,204,336,233,23,218,297,53,252,28,267,265,201,284,234,201,49,198,283,66,49,134,305,25,218,64,69,245,133,184,358,150,51,320,337,172,45,304,46,52,277,312,199,150,369,174,248,191,154,173,194,311,134,365,236,30,211,310,196,174,221,269,260,288,292,284,299,155,240,219,171,206,52,316,367,263,368,250,247,296,252,73,67,40,237,75,361,203,190,170,261,258,177,361,197,177,340,170,117,331,196,37,157,75,158,291,333,267,247,323,270,302,302,54,57,22,191,302,263,57,28,136,45,218,275,165,174,161,360,20,372,30,277,25,172,190,35,24,364,365,155,113,374,232,277,219,186,183,236,254,246,275,223,246,170,368,189,362,366,43,76,44,256,364,53,298,47,373,58,215,319,97,185,294,260,57,365,20,282,99,192,227,157,184,228,40,197,50,43,187,334,25,67,367,299,290,371,116,236,30,185,187,189,267,219,372,288,150,30,31,45,61,185,246,138,157,194,129,266,22,318,262,165,288,318,233,185,335,276,247,195,24,22,284,39,289,75,218,57,47,227,59,54,253,234,309,183,205,241,361,365,139,280,355,179,239,219,71,219,163,185,80,33,247,148,177,145,204,365,158,261,359,290,70,281,72,128,309,361,121,280,177,26,372,218,24,206,332,243,191,253,18,239,50,130,312,170,276,87,373,21,228,24,44,136,236,261,253,185,170,321,232,373,113,235,359,263,255,159,281,30,74,37,191,51,33,218,373,369,143,205,170,174,365,304,56,225,44,23,85,165,247,374,310,282,373,138,160,131,37,199,249,66,117,142,372,374,166,211,52,145,185,237,225,282,257,81,108,99,334,65,203,359,288,75,289,258,217,274,61,313,127,330,369,214,243,211,295,361,46,51,301,354,192,262,106,29,326,237,89, ...

# %%
correlation_matrix = rfm[['R', 'F', 'M']].corr()

# %%
fig_heatmap = go.Figure(data=go.Heatmap(
                   z=correlation_matrix.values,
                   x=correlation_matrix.columns,
                   y=correlation_matrix.columns,
                   colorscale='Viridis',
                   colorbar=dict(title='Correlation')))

fig_heatmap.update_layout(title='Correlation Heatmap')
fig_heatmap.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31bc0497-ef79-4f1b-a6bf-c66d0481ea6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31bc0497-ef79-4f1b-a6bf-c66d0481ea6c")) {                    Plotly.newPlot(                        "31bc0497-ef79-4f1b-a6bf-c66d0481ea6c",                        [{"colorbar":{"title":{"text":"Correlation"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":["R","F","M"],"y":["R","F","M"],"z":[[1.0,0.47332096767924686,0.46112171322783346],[0.47332096767924686,1.0,0.7507790163985318],[0.46112171322783346,0.7507790163985318,1.0]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width" ...

# %%
pastel_colors = plotly.colors.qualitative.Pastel

# Corrected code to create a bar chart using plotly.graph_objects
fig = go.Figure(data=[go.Bar(x=segment_counts['RFM_Customer_Segments'], y=segment_counts['Count'],
                             marker=dict(color=pastel_colors))])

# Update the layout
fig.update_layout(title='Distribution of RFM Customer Segments',
                  xaxis_title='RFM Segment',
                  yaxis_title='Number of Customers',
                  showlegend=False)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d32ef762-75e2-4194-a541-d73f86a6da20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d32ef762-75e2-4194-a541-d73f86a6da20")) {                    Plotly.newPlot(                        "d32ef762-75e2-4194-a541-d73f86a6da20",                        [{"marker":{"color":["rgb(102, 197, 204)","rgb(246, 207, 113)","rgb(248, 156, 116)","rgb(220, 176, 242)","rgb(135, 197, 95)","rgb(158, 185, 243)","rgb(254, 136, 177)","rgb(201, 219, 116)","rgb(139, 224, 164)","rgb(180, 151, 231)","rgb(179, 179, 179)"]},"x":["AT Risk Customers","Lost","Potential Loyal","Vip\u002fLoyal"],"y":[1382,391,1690,909],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterp ...

# %%
segment_scores = rfm.groupby('RFM_Customer_Segments')[['R','F','M']].mean().reset_index()
fig = go.Figure()

#ADD bars for Recency score
fig.add_trace(go.Bar(
    x=segment_scores['RFM_Customer_Segments'],
    y=segment_scores['R'],
    name='Recency',
    marker_color='blue'
))

#Add bars for Ferquency score
fig.add_trace(go.Bar(
    x=segment_scores['RFM_Customer_Segments'],
    y=segment_scores['F'],
    name='Frequency Score',
    marker_color='green'
))

#Add bars for Monetary score
fig.add_trace(go.Bar(
    x=segment_scores['RFM_Customer_Segments'],
    y=segment_scores['M'],
    name='Monetary Score',
    marker_color='red'
))

#Update the layout
fig.update_layout(
    title='Comparison of rfm Segments based on Recency,Frequency,and Monetary Scores',
    xaxis_title='RFM Segment',
    yaxis_title='Score',
    barmode='group'
)

#Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35a6909d-7735-4e85-8481-f738c8395c70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35a6909d-7735-4e85-8481-f738c8395c70")) {                    Plotly.newPlot(                        "35a6909d-7735-4e85-8481-f738c8395c70",                        [{"marker":{"color":"blue"},"name":"Recency","x":["AT Risk Customers","Lost","Potential Loyal","Vip\u002fLoyal"],"y":[2.444283646888567,1.462915601023018,3.4041420118343195,1.4180418041804181],"type":"bar"},{"marker":{"color":"green"},"name":"Frequency Score","x":["AT Risk Customers","Lost","Potential Loyal","Vip\u002fLoyal"],"y":[2.2532561505065125,1.2736572890025575,3.568639053254438,1.3553355335533552],"type":"bar"},{"marker":{"color":"red"},"name":"Monetary Score","x":["AT Risk Customers","Lost","Potential Loyal","Vip\u002fLoyal"],"y":[2.3017366136034734,1.2634271099744245,3.559171597633136,1.364136413641364],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"erro ...
